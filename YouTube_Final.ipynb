# %%
import os
from googleapiclient.discovery import build
import pandas as pd
import json

# %%
api_key = 'AIzaSyAbUPGkECjLGTipq6KipdkOrfg5KXX5QBg'
youtube = build('youtube', 'v3', developerKey=api_key)

# api_key = "AIzaSyCkglXpsoXo7QjsLDBAL8mzCfX4YZzpdtg"

# %%
# Function to get channel information
def get_channel_info(channel_id):
    try:
        print(f"Fetching info for Channel ID: {channel_id}")
        request = youtube.channels().list(
            part="snippet,contentDetails,statistics",
            id=channel_id
        )
        response = request.execute()
        print(f"Channel API Response: {response}")  # Debug statement

        if 'items' in response and len(response['items']) > 0:
            channel = response['items'][0]
            uploads_playlist_id = channel['contentDetails']['relatedPlaylists']['uploads']
            if uploads_playlist_id:
                channel_info = {
                    'channel_id': channel_id,
                    'channel_name': channel['snippet']['title'],
                    'channel_description': channel['snippet']['description'],
                    'channel_views': channel['statistics']['viewCount'], 
                    'Channel_subscriber_count': channel["statistics"]["subscriberCount"],
                    'Channel_video_count': channel["statistics"]["videoCount"],
                    'channel_type': 'N/A',  # This information is not available directly from the API
                    'channel_status': 'N/A'  # This information is not available directly from the API
                }
                return channel_info, uploads_playlist_id
            else:
                print("Error: uploads_playlist_id is None or invalid.")
        else:
            print("Error: Channel information not found in API response.")
    
    except Exception as e:
        print(f"An error occurred: {e}")
    return None, None

# Function to get playlist information
def get_playlist_info(playlist_id):
    try:
        print(f"Fetching info for Playlist ID: {playlist_id}")
        request = youtube.playlists().list(
            part="snippet",
            id=playlist_id
        )
        response = request.execute()
        print(f"Playlist API Response: {response}")  # Debug statement
        
        if 'items' in response and len(response['items']) > 0:
            playlist = response['items'][0]
            playlist_info = {
                'playlist_id': playlist_id,
                'playlist_name': playlist['snippet']['title']
            }
            return playlist_info
    
        else:
            print("Error: Playlist information not found in API response.")
    
    except Exception as e:
        print(f"An error occurred: {e}")
    return None

# Function to get videos in a playlist
def get_videos_in_playlist(playlist_id):
    try:
        print(f"Fetching videos for Playlist ID: {playlist_id}")
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults=50
        )
        response = request.execute()
        
        videos = []
        for item in response['items']:
            video_id = item['contentDetails']['videoId']
            video_info = get_video_info(video_id)
            if video_info:
                videos.append(video_info)
        
        return videos
    except Exception as e:
        print(f"An error occurred while fetching videos: {e}")
        return []

# Function to get video information
def get_video_info(video_id):
    try:
        request = youtube.videos().list(
            part="snippet,statistics,contentDetails",
            id=video_id
        )
        response = request.execute()
        
        if 'items' in response and len(response['items']) > 0:
            video = response['items'][0]
            video_info = {
                'video_id': video_id,
                'video_name': video['snippet']['title'],
                'video_description': video['snippet']['description'],
                'published_date': video['snippet']['publishedAt'],
                'view_count': video['statistics'].get('viewCount', 0),
                'like_count': video['statistics'].get('likeCount', 0),
                'dislike_count': video['statistics'].get('dislikeCount', 0),
                'favorite_count': video['statistics'].get('favoriteCount', 0),
                'comment_count': video['statistics'].get('commentCount', 0),
                'duration': video['contentDetails']['duration'],
                'thumbnail': video['snippet']['thumbnails']['default']['url'],
                'caption_status': video['contentDetails']['caption']
            }
            return video_info
        else:
            print("Error: Video information not found in API response.")
    except Exception as e:
        print(f"An error occurred while fetching video information: {e}")
    return None

# Function to get comments for a video from YouTube API
def get_comments(video_id):
    try:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=50
        )
        response = request.execute()

        comments = []
        for item in response['items']:
            snippet = item.get('snippet', {}).get('topLevelComment', {}).get('snippet', {})
            comment_id = item.get('id', '')
            comment_text = snippet.get('textDisplay', '')
            comment_author = snippet.get('authorDisplayName', '')
            comment_published_date = snippet.get('publishedAt', '')

            if comment_id and comment_text and comment_author and comment_published_date:
                comments.append({
                    'comment_id': comment_id,
                    'comment_text': comment_text,
                    'comment_author': comment_author,
                    'comment_published_date': comment_published_date
                })
        return comments
    except Exception as e:
        print(f"An error occurred while fetching comments: {e}")
        return []

# %%
# Replace with your desired channel ID
channel_id = 'UCmmsAsZx40YSA_aBKKNQtBQ' # Kaleeshwari Ramkumar

channel_info, uploads_playlist_id = get_channel_info(channel_id)
if uploads_playlist_id:
    playlist_info = get_playlist_info(uploads_playlist_id)

    if channel_info and playlist_info:
        videos = get_videos_in_playlist(uploads_playlist_id)
        
        all_data = []
        for video in videos:
            comments = get_comments(video['video_id'])
            for comment in comments:
                combined_info = {**channel_info, **playlist_info, **video, **comment}
                all_data.append(combined_info)
        
        df = pd.DataFrame(all_data)
        print(df)
    else:
        print("Channel or Playlist not found")
else:
    print("Error: playlist_id is None or invalid.")
# Out:
# Fetching info for Channel ID: UCmmsAsZx40YSA_aBKKNQtBQ
# Channel API Response: {'kind': 'youtube#channelListResponse', 'etag': 'qHMTRV1d4_a6MPUGNEWqbCd3WoI', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'z6S66ofxtO8700ha2MOoAMzBzc8', 'id': 'UCmmsAsZx40YSA_aBKKNQtBQ', 'snippet': {'title': 'Kaleeswari Ramkumar', 'description': 'Hi Friends,', 'customUrl': '@rkaleeswari-08', 'publishedAt': '2023-12-28T05:32:06.370058Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mxd3Qels4-xHG3jli3CCXRdd38xpNrGdrKkcMeYrs_ytayMuPl1b50TqCPD-gw609mTw=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mxd3Qels4-xHG3jli3CCXRdd38xpNrGdrKkcMeYrs_ytayMuPl1b50TqCPD-gw609mTw=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mxd3Qels4-xHG3jli3CCXRdd38xpNrGdrKkcMeYrs_ytayMuPl1b50TqCPD-gw609mTw=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'Kaleeswari Ramkumar', 'description': 'Hi Friends,'}}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUmmsAsZx40YSA_aBKKNQtBQ'}}, 'statistics': {'viewCount': '236', 'subscriberCount': '7', 'hiddenSubscriberCount': False, 'videoCount': '3'}}]}
# Fetching info for Playlist ID: UUmmsAsZx40YSA_aBKKNQtBQ
# Playlist API Response: {'kind': 'youtube#playlistListResponse', 'etag': 'Rd58B1-qECpjg33T2npBiJi3c_U', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#playlist', 'etag': '2NJj3Xxr2GtVTwHmb4kDvn-zNTQ', 'id': 'UUmmsAsZx40YSA_aBKKNQtBQ', 'snippet': {'publishedAt': '2023-12-29T08:03:20Z', 'channelId': 'UCmmsAsZx40YSA_aBKKNQtBQ', 'title': 'Uploads from Kaleeswari Ramkumar', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Kaleeswari Ramkumar', 'defaultLanguage': 'en', 'localized': {'title': 'Uploads from Kaleeswari Ramkumar', 'description': ''}}}]}
# Fetching videos for Playlist ID: UUmmsAsZx40YSA_aBKKNQtBQ
# An error occurred while fetching comments: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=NKA8EMtLxS0&maxResults=50&key=AIzaSyAbUPGkECjLGTipq6KipdkOrfg5KXX5QBg&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#                  channel_id         channel_name channel_description  \
# 0  UCmmsAsZx40YSA_aBKKNQtBQ  Kaleeswari Ramkumar         Hi Friends,
# 1  UCmmsAsZx40YSA_aBKKNQtBQ  Kaleeswari Ramkumar         Hi Friends,
#
#   channel_views Channel_subscriber_count Channel_video_count channel_type  \
# 0           236                        7                   3          N/A
# 1           236                        7                   3          N/A
#
#   channel_status               playlist_id                     playlist_name  \
# 0            N/A  UUmmsAsZx40YSA_aBKKNQtBQ  Uploads from Kaleeswari Ramkumar
# 1            N/A  UUmmsAsZx40YSA_aBKKNQtBQ  Uploads from Kaleeswari Ramkumar
#
#    ... dislike_count favorite_count comment_count duration  \
# 0  ...             0              0             3  PT12M9S
# 1  ...             0              0             3  PT12M9S
#
#                                         thumbnail caption_status  \
# 0  https://i.ytimg.com/vi/S38jA79loGs/default.jpg          false
# 1  https://i.ytimg.com/vi/S38jA79loGs/default.jpg          false
#
#                    comment_id  \
# 0  UgxERc_mXX5AJSoKDop4AaABAg
# 1  UgxVOW-rn7ipxZzJinl4AaABAg
#
#                                         comment_text        comment_author  \
# 0                Hi can u help me to do this project  @rihanafcparveen9530
# 1  If u want detailed explanation about this proj...       @RKaleeswari-08
#
#   comment_published_date
# 0   2024-05-24T03:51:13Z
# 1   2024-01-03T06:10:22Z
#
# [2 rows x 26 columns]

# %%
df.head()
# Out:
#                  channel_id         channel_name channel_description  \
# 0  UCmmsAsZx40YSA_aBKKNQtBQ  Kaleeswari Ramkumar         Hi Friends,
# 1  UCmmsAsZx40YSA_aBKKNQtBQ  Kaleeswari Ramkumar         Hi Friends,
#
#   channel_views Channel_subscriber_count Channel_video_count channel_type  \
# 0           236                        7                   3          N/A
# 1           236                        7                   3          N/A
#
#   channel_status               playlist_id                     playlist_name  \
# 0            N/A  UUmmsAsZx40YSA_aBKKNQtBQ  Uploads from Kaleeswari Ramkumar
# 1            N/A  UUmmsAsZx40YSA_aBKKNQtBQ  Uploads from Kaleeswari Ramkumar
#
#    ... dislike_count favorite_count comment_count duration  \
# 0  ...             0              0             3  PT12M9S
# 1  ...             0              0             3  PT12M9S
#
#                                         thumbnail caption_status  \
# 0  https://i.ytimg.com/vi/S38jA79loGs/default.jpg          false
# 1  https://i.ytimg.com/vi/S38jA79loGs/default.jpg          false
#
#                    comment_id  \
# 0  UgxERc_mXX5AJSoKDop4AaABAg
# 1  UgxVOW-rn7ipxZzJinl4AaABAg
#
#                                         comment_text        comment_author  \
# 0                Hi can u help me to do this project  @rihanafcparveen9530
# 1  If u want detailed explanation about this proj...       @RKaleeswari-08
#
#   comment_published_date
# 0   2024-05-24T03:51:13Z
# 1   2024-01-03T06:10:22Z
#
# [2 rows x 26 columns]

# %% [raw]
# '' #NK tunes - 6 videos
# 'UCO_NXoD5FC9H58ymRCDECAQ'  # Kannada music - 8 videos
# 'UCuI5XcJYynHa5k_lqDzAgwQ'  # Data Science Tamil -71 videos
# 'UCFQec-pTNXd8qtdOdtUULwg'  # Leron's universe - 38 videos
# 'UC58aOfdkdPKu0na-1hi5d6w' # Miracle makers -15 videos
# 'UCLH5ojAg1XIyxcOCazK4n-Q' # Alka Yagnik - 03 videos
# 'UCeMdpc7DBqGS58shLa7DOYg' # World funny animals - 70 videos
# 'UCmmsAsZx40YSA_aBKKNQtBQ' # Kaleeshwari Ramkumar - 3 videos

# %%
import pymongo
from pymongo import MongoClient

# Connect to MongoDB 
client = pymongo.MongoClient("mongodb+srv://hema_mukundan:ALMh_gr43SdABra@cluster0.ivcubxu.mongodb.net/")
mydb = client["YT_Project"]
channel_collection = mydb['yt_channels']

# %%
# Function to migrate channel data to MongoDB
def migrate_data_to_mongodb(channel_id):
    channel_info, uploads_playlist_id = get_channel_info(channel_id)
    if channel_info and uploads_playlist_id:
        playlist_info = get_playlist_info(uploads_playlist_id)
        if playlist_info:
            channel_info['playlists'] = [playlist_info]
            videos = get_videos_in_playlist(uploads_playlist_id)
            playlist_info['videos'] = videos
        
        channel_collection.update_one(
            {'channel_id': channel_info['channel_id']},
            {'$set': channel_info},
            upsert=True
        )
        print("Data migration to MongoDB completed successfully!")
    else:
        print("Channel or Playlist not found")

# Replace with the desired channel ID
channel_id = 'UCmmsAsZx40YSA_aBKKNQtBQ' # Kaleeshwari Ramkumar
migrate_data_to_mongodb(channel_id)
# Out:
# Fetching info for Channel ID: UCmmsAsZx40YSA_aBKKNQtBQ
# Channel API Response: {'kind': 'youtube#channelListResponse', 'etag': 'qHMTRV1d4_a6MPUGNEWqbCd3WoI', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'z6S66ofxtO8700ha2MOoAMzBzc8', 'id': 'UCmmsAsZx40YSA_aBKKNQtBQ', 'snippet': {'title': 'Kaleeswari Ramkumar', 'description': 'Hi Friends,', 'customUrl': '@rkaleeswari-08', 'publishedAt': '2023-12-28T05:32:06.370058Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mxd3Qels4-xHG3jli3CCXRdd38xpNrGdrKkcMeYrs_ytayMuPl1b50TqCPD-gw609mTw=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mxd3Qels4-xHG3jli3CCXRdd38xpNrGdrKkcMeYrs_ytayMuPl1b50TqCPD-gw609mTw=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AIdro_mxd3Qels4-xHG3jli3CCXRdd38xpNrGdrKkcMeYrs_ytayMuPl1b50TqCPD-gw609mTw=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'Kaleeswari Ramkumar', 'description': 'Hi Friends,'}}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUmmsAsZx40YSA_aBKKNQtBQ'}}, 'statistics': {'viewCount': '236', 'subscriberCount': '7', 'hiddenSubscriberCount': False, 'videoCount': '3'}}]}
# Fetching info for Playlist ID: UUmmsAsZx40YSA_aBKKNQtBQ
# Playlist API Response: {'kind': 'youtube#playlistListResponse', 'etag': 'Rd58B1-qECpjg33T2npBiJi3c_U', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#playlist', 'etag': '2NJj3Xxr2GtVTwHmb4kDvn-zNTQ', 'id': 'UUmmsAsZx40YSA_aBKKNQtBQ', 'snippet': {'publishedAt': '2023-12-29T08:03:20Z', 'channelId': 'UCmmsAsZx40YSA_aBKKNQtBQ', 'title': 'Uploads from Kaleeswari Ramkumar', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/NKA8EMtLxS0/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Kaleeswari Ramkumar', 'defaultLanguage': 'en', 'localized': {'title': 'Uploads from Kaleeswari Ramkumar', 'description': ''}}}]}
# Fetching videos for Playlist ID: UUmmsAsZx40YSA_aBKKNQtBQ
# Data migration to MongoDB completed successfully!

# %%
def fetch_channel_data():
    return list(channel_collection.find({}))

channel_data = fetch_channel_data()
print(channel_data)
# Out:
# [{'_id': ObjectId('6672bc7f91ff6676a53c6144'), 'channel_id': 'UCUTFzS4NXoxfFNIPLJPFnpw', 'Channel subscriber count': '123', 'Channel video count': '6', 'channel_description': '', 'channel_name': 'NK Tunes...', 'channel_status': 'N/A', 'channel_type': 'N/A', 'channel_views': '7677', 'playlists': [{'playlist_id': 'UUUTFzS4NXoxfFNIPLJPFnpw', 'playlist_name': 'Uploads from NK Tunes...', 'videos': [{'video_id': 'acQrarQ9PIo', 'video_name': 'Mugulu Nage | Kalimba | Kannada melody songs', 'video_description': '#kalimba#kanndasongs#kannada', 'published_date': '2023-07-19T15:32:00Z', 'view_count': '526', 'like_count': '29', 'dislike_count': 0, 'favorite_count': '0', 'comment_count': '7', 'duration': 'PT1M1S', 'thumbnail': 'https://i.ytimg.com/vi/acQrarQ9PIo/default.jpg', 'caption_status': 'false'}, {'video_id': 'keBOAeyXKYE', 'video_name': 'Let go.... (Spiderman into the the Spiderverse)... Lyrical YT shorts....NK tunes', 'video_description': '#Whatsapp status video\n#english song\n#sad song\n#lonely whatsapp status', 'published_date': '2022-01-31T02:13:19Z', 'view_count': '437', 'like_count': '17', 'dislike_count': 0, 'favorite_count': '0', 'comment_count': '0', 'duration': 'PT43S', 'thumbnail': 'https://i.ytimg.com/vi/keBOAeyXKYE/default.jpg', 'caption_status': 'false'}, {'video_id': '4EBfL_PHGTU', 'video_name': 'Neenade na Kannada song (Kalimba tutorial and cover) | Yuvaratna movie | NK tunes', 'video_description': 'Neenade Na song from Yuvaratna kannada movie...I have made Kalimba cover (instrumental) as well as Tutorial...I hope it might help you to learn this song....Happy learning :)\n___________________________________________\nTo understand my notes and to know about kalimba:-\nhttps://drive.google.com/file/d/1NeOSY2k3wSiKi_-jL01q3RbJgvykIQ4a/view?usp=sharing\n_____________________________________________\nNeenade na Kalimba notes PDF:-\nhttps://drive.google.com/file/d/1WAJ-mXGYk2zEcCfY1luN5q6gFZZ4A4uK/view?usp=sharing\n\nParts of learning:-\nIntro:- (0:00)\nPart 1:- (0:27)\nPart2:-  (1:04)\nPart 3:- (1:35)\nPart 4:- (1:50)\nPart 5:- (2:04)  \nPart 6:- (2:19) \n\n______________________________________________\nTo listen original song:-\nhttps://youtu.be/3kxerdAFlv0\n_______________________________________________\n\nThank you....Keep supporting..Subscribe,Like and share for more tutorials videos and covers...', 'published_date': '2021-08-21T11:59:26Z', 'view_count': '999', 'like_count': '49', 'dislike_count': 0, 'favorite_count': '0', 'comment_count': '20', 'duration': 'PT2M46S', 'thumbnail': 'https://i.ytimg.com/vi/4EBfL_PHGTU/default.jpg', 'caption_status': 'false'}, {'video_id': 'etyjGZ4kgPs', 'video_name': 'The Conductors by LKC (Kalimba tutorial) | NK tunes |', 'video_description': "The Conductors song (Tiktok song) by LKC played in Kalimba and it's tutorial...I hope you enjoyed it...happy learning :)\n____________________________________________________________ \nTo understand my notes and to know about kalimba:-\nhttps://drive.google.com/file/d/1NeOS...\n____________________________________________________________\nTo listen original tune:-\nhttps://youtu.be/knFAineMy3g\n---------------------------------------------------------------------------------------------------\n\nThank you, like ,share and subscribe for more videos..", 'published_date': '2021-08-11T16:01:29Z', 'view_count': '562', 'like_count': '47', 'dislike_count': 0, 'favorite_count': '0', 'comment_count': '6', 'duration': 'PT44S', 'thumbnail': 'https://i.ytimg.com/vi/etyjGZ4kgPs/default.jpg', 'caption_status': 'false'}, {'video_id': 'XzXnWK2puQM', 'video_name': 'Om shanti Om theme [Kalimba tutorial] | NK Tunes', 'video_description': "Om shanti Om theme [Kalimba tutorial] ,I hope you enjoyed my tutorial if video seems to be speed to learn ,you can slow down the speed of the video by clicking three dots at right corner.\n\nDon't forget to hit like, subscribe and share...\n\nThank you :)\n------------------------------------------------------------------------ ...

# %%
import mysql.connector

# Connect to the MySQL database
connection = mysql.connector.connect(
                host="localhost",
                user="root",
                password="Data23Wrangl#",
                database='yt_db'
                )

cursor = connection.cursor(buffered=True)

# %%
# SQL script to create database 
sql_script = """
CREATE DATABASE IF NOT EXISTS yt_db;
"""
cursor.execute(sql_script)
connection.commit()

print("Database yt_db created successfully")
# Out:
# Database yt_db created successfully

# %%
sql_script = """
USE yt_db;

CREATE TABLE IF NOT EXISTS channel (
    channel_id VARCHAR(255) PRIMARY KEY,
    channel_name VARCHAR(255) NOT NULL,
    channel_type VARCHAR(255),
    channel_views INT,
    channel_description TEXT,
    channel_status VARCHAR(255)
    
); """
# Execute the SQL script
for statement in sql_script.split(';'):
    if statement.strip():
        cursor.execute(statement)
connection.commit()
print("Channel table created successfully!")
# Out:
# Channel table created successfully!

# %%
cursor = connection.cursor()
sql_script = """
USE yt_db;
CREATE TABLE IF NOT EXISTS playlist (
    playlist_id VARCHAR(255) PRIMARY KEY,
    channel_id VARCHAR(255),
    playlist_name VARCHAR(255) NOT NULL
);"""

# Execute the SQL script
for statement in sql_script.split(';'):
    if statement.strip():
        cursor.execute(statement)
connection.commit()

print("Playlist table created successfully!")
# Out:
# Playlist table created successfully!

# %%
sql_script = """
CREATE TABLE IF NOT EXISTS comment (
    comment_id VARCHAR(255) PRIMARY KEY,
    video_id VARCHAR(255),
    comment_text TEXT NOT NULL,
    comment_author VARCHAR(255),
    comment_published_date DATETIME
);
"""
# Execute the SQL script
for statement in sql_script.split(';'):
    if statement.strip():
        cursor.execute(statement)
connection.commit()
print("Comment table created successfully!")
# Out:
# Comment table created successfully!

# %%
sql_script = """
CREATE TABLE IF NOT EXISTS video (
    video_id VARCHAR(255) PRIMARY KEY,
    playlist_id VARCHAR(255),
    video_name VARCHAR(255) NOT NULL,
    video_description TEXT,
    published_date DATETIME,
    view_count INT,
    like_count INT,
    dislike_count INT,
    favorite_count INT,
    comment_count INT,
    duration INT,
    thumbnail VARCHAR(255),
    caption_status VARCHAR(255)
);"""

# Execute the SQL script
for statement in sql_script.split(';'):
    if statement.strip():
        cursor.execute(statement)
connection.commit()

print("Video table created successfully!")
# Out:
# Video table created successfully!

# %%
from datetime import datetime

youtube_datetime_str = video['published_date']
formatted_datetime = datetime.strptime(youtube_datetime_str, "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d %H:%M:%S")

# %%
import re

def convert_duration(duration_str):
    # Initialize variables for hours, minutes, and seconds
    hours = 0
    minutes = 0
    seconds = 0

    # Regular expression to parse ISO 8601 duration
    pattern = re.compile(r'PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?')
    match = pattern.match(duration_str)

    if match:
        if match.group(1):  # hours
            hours = int(match.group(1))
        if match.group(2):  # minutes
            minutes = int(match.group(2))
        if match.group(3):  # seconds
            seconds = int(match.group(3))

    # Calculate total duration in seconds
    total_seconds = hours * 3600 + minutes * 60 + seconds
    return total_seconds

# %%
import mysql.connector
from datetime import datetime

# Function to fetch comment data from MongoDB
def fetch_videos_from_mongodb():
    videos = []
    for channel in channel_collection.find():
        for playlist in channel.get('playlists', []):
            videos.extend(playlist.get('videos', []))
    return videos

# Connect to the MySQL database
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Data23Wrangl#",
    database='yt_db'
)

try:
    cursor = connection.cursor(buffered=True)

    # Insert into channel table
    try:
        channel_data = channel_collection.find()
        for channel in channel_data:
            if all(key in channel for key in ('channel_id', 'channel_name', 'channel_description', 'channel_views', 'channel_type', 'channel_status')):
                channel_insert_query = """
                    INSERT INTO channel (channel_id, channel_name, channel_description, channel_views, channel_type, channel_status)
                    VALUES (%s, %s, %s, %s, %s, %s)
                    ON DUPLICATE KEY UPDATE
                    channel_name=VALUES(channel_name), channel_description=VALUES(channel_description), channel_views=VALUES(channel_views),
                    channel_type=VALUES(channel_type), channel_status=VALUES(channel_status);
                """
                cursor.execute(channel_insert_query, (
                    channel['channel_id'], channel['channel_name'], channel['channel_description'], channel['channel_views'],
                    channel['channel_type'], channel['channel_status']
                ))
            else:
                print(f"Channel data: {channel}")
        
        connection.commit()
        print("Channels inserted/updated successfully")

    except Exception as e:
        print(f"Error processing channels: {e}")

    # Insert into playlist table and loop through videos
    try:
        for channel in channel_collection.find():
            for playlist in channel.get('playlists', []):
                playlist_insert_query = """
                    INSERT INTO playlist (playlist_id, playlist_name, channel_id)
                    VALUES (%s, %s, %s)
                    ON DUPLICATE KEY UPDATE
                    playlist_name=VALUES(playlist_name), channel_id=VALUES(channel_id);
                """
                cursor.execute(playlist_insert_query, (
                    playlist['playlist_id'], playlist['playlist_name'], channel['channel_id']
                ))
                connection.commit()
                print(f"Inserted or updated playlist {playlist['playlist_id']}")

                # Loop through videos and insert into MySQL
                for video in playlist.get('videos', []):
                    try:
                        formatted_duration = convert_duration(video['duration'])
                        formatted_datetime = datetime.strptime(video['published_date'], "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d %H:%M:%S")
                
                        video_insert_query = """
                            INSERT INTO video (video_id, playlist_id, video_name, video_description, published_date,
                            view_count, like_count, dislike_count, favorite_count, comment_count,
                            duration, thumbnail, caption_status)
                            VALUES (%s, %s, %s, %s, %s,
                            # %s, %s, %s, %s, %s, %s, %s, %s)
                            ON DUPLICATE KEY UPDATE
                            playlist_id=VALUES(playlist_id), video_name=VALUES(video_name),
                            video_description=VALUES(video_description),
                            published_date=VALUES(published_date), view_count=VALUES(view_count),
                            like_count=VALUES(like_count), dislike_count=VALUES(dislike_count),
                            favorite_count=VALUES(favorite_count), comment_count=VALUES(comment_count),
                            duration=VALUES(duration), thumbnail=VALUES(thumbnail),
                            caption_status=VALUES(caption_status);
                        """
                
                        cursor.execute(video_insert_query, (
                            video['video_id'], playlist['playlist_id'], video['video_name'],
                            video['video_description'], formatted_datetime, video['view_count'],
                            video['like_count'], video['dislike_count'], video['favorite_count'],
                            video['comment_count'], formatted_duration, video['thumbnail'],
                            video['caption_status']
                        ))
                        connection.commit()
                        print(f"Inserted/updated video {video['video_id']}")
                
                    except Exception as e:
                        print(f"Error inserting video {video['video_id']}: {e}")
                    
    except Exception as e:
        print(f"Error inserting playlists: {e}")

    # Fetch video data from MongoDB
    videos = fetch_videos_from_mongodb()

    # Loop through videos and insert comments into MySQL
    for video in videos:
        video_id = video['video_id']
        print(f"Processing video: {video_id}")

        # Fetch comments for the current video
        comments = get_comments(video_id)
        print(f"Comments for video {video_id}: {comments}")

        try:
            cursor.execute("SELECT video_id FROM video WHERE video_id = %s", (video_id,))
            if cursor.fetchone():  # If video_id exists in video table
                for comment in comments:
                    try:
                        comment_published_date = datetime.strptime(comment['comment_published_date'], "%Y-%m-%dT%H:%M:%SZ").strftime("%Y-%m-%d %H:%M:%S")
                        comment_insert_query = """
                            INSERT INTO comment (comment_id, video_id, comment_text, comment_author, comment_published_date)
                            VALUES (%s, %s, %s, %s, %s)
                            ON DUPLICATE KEY UPDATE
                            video_id=VALUES(video_id), comment_text=VALUES(comment_text), 
                            comment_author=VALUES(comment_author), comment_published_date=VALUES(comment_published_date);
                        """
                        cursor.execute(comment_insert_query, (
                            comment['comment_id'], video_id, comment['comment_text'], 
                            comment['comment_author'], comment_published_date
                        ))

                        print(f"Inserted/Updated comment {comment['comment_id']} for video {video_id}")

                    except Exception as e:
                        print(f"Error inserting comment {comment['comment_id']} for video {video_id}: {e}")
            else:
                print(f"Video with video_id {video_id} does not exist in the video table.")

        except Exception as e:
            print(f"Error checking video_id {video_id} existence or fetching comments: {e}")

    connection.commit()

except Exception as e:
    print(f"Error: {e}")

finally:
    # Close cursor and connection
    if 'cursor' in locals() and cursor:
        cursor.close()
    if 'connection' in locals() and connection:
        connection.close()
    print("MySQL connection closed.")
# Out:
# Channels inserted/updated successfully
# Inserted or updated playlist UUUTFzS4NXoxfFNIPLJPFnpw
# Inserted/updated video acQrarQ9PIo
# Inserted/updated video keBOAeyXKYE
# Inserted/updated video 4EBfL_PHGTU
# Inserted/updated video etyjGZ4kgPs
# Inserted/updated video XzXnWK2puQM
# Inserted/updated video FkOL_uySa20
# Inserted or updated playlist UUO_NXoD5FC9H58ymRCDECAQ
# Inserted/updated video EE7mHmpKddw
# Inserted/updated video nteaQoj3mJw
# Inserted/updated video 4Gakw4llegA
# Inserted/updated video 30TC0i9WvcI
# Inserted/updated video EtMqqd4ObMg
# Inserted/updated video Ru5BxzYTS5A
# Inserted/updated video k7-XqimyVek
# Inserted or updated playlist UUuI5XcJYynHa5k_lqDzAgwQ
# Inserted/updated video JdyZ-ek67bI
# Inserted/updated video jzpoKhGC_OM
# Inserted/updated video be97AndjHCM
# Inserted/updated video uAqwxNaaMtg
# Inserted/updated video GGDAZj-xXnw
# Inserted/updated video 9rFODpR2pc8
# Inserted/updated video J-B2uxGujwc
# Inserted/updated video lBiweoUQL1A
# Inserted/updated video 85vZbb2skIw
# Inserted/updated video Qftj5XU133Q
# Inserted/updated video PPbIg3nLArk
# Inserted/updated video 3ELkF2mrJGQ
# Inserted/updated video 1DJDLibr3Xw
# Inserted/updated video 65VTeSuYyps
# Inserted/updated video ZTNnojP6QE4
# Inserted/updated video ty7D_X1Dn18
# Inserted/updated video 2YhFIbhGzGk
# Inserted/updated video SYQETrGd4bo
# Inserted/updated video d62FsKPzV-M
# Inserted/updated video hzCkDbyToCA
# Inserted/updated video deEG8VCxmFQ
# Inserted/updated video Q13Ab3J9JXU
# Inserted/updated video tadK65KehvA
# Inserted/updated video HoX7T7BsqAs
# Inserted/updated video bbbi0RAMrZo
# Inserted/updated video D0pWDo0x5ao
# Inserted/updated video hdOny_O8Qxg
# Inserted/updated video gdNrhpiaMqk
# Inserted/updated video wLrzbanUVKs
# Inserted/updated video VOxOJMlpbw0
# Inserted/updated video ZaWHSsqo2Fw
# Inserted/updated video VKySXPjmUzo
# Inserted/updated video F11BVRciggQ
# Inserted/updated video OqYYuu96zyQ
# Inserted/updated video B7JUo06WX4I
# Inserted/updated video AYyg2rQOVIc
# Inserted/updated video k3n2FXSbhd4
# Inserted/updated video eyHCv3KLFrA
# Inserted/updated video nR9eaYYtdQ4
# Inserted/updated video ht_nS8TjQmY
# Inserted/updated video FLDy71gP29A
# Inserted/updated video FVQSly4AGh0
# Inserted/updated video WV5z24-4Z04
# Inserted/updated video 1DCdv1sKdeQ
# Inserted/updated video LT0rmxunQHI
# Inserted/updated video YPEPOkGJPv4
# Inserted/updated video V29V4bATwPE
# Inserted/updated video XVRh_Gs3kT0
# Inserted/updated video h_Ph2tt9SwU
# Inserted/updated video wX--Clg_aiA
# Inserted or updated playlist UUFQec-pTNXd8qtdOdtUULwg
# Inserted/updated video NCG3iJDDrm0
# Inserted/updated video e0xqd1_WJTw
# Inserted/updated video qgL2m913zIc
# Inserted/updated video 0eQkEGdHO9E
# Inserted/updated video pYiw2HJUo5A
# Inserted/updated video X0C1y9na0UU
# Inserted/updated video UQNm07wZERk
# Inserted/updated video IFgh9MBNQsc
# Inserted/updated video piEL2TJI3xo
# Inserted/updated video w6Sbf1_Mp0Q
# Inserted/updated video 8HMwxybXSzw
# Inserted/updated video 8kSr9y3bpKY
# Inserted/updated video -_D37wHAgCo
# Inserted/updated video eon4kz5v0qo
# Inserted/updated video N3B-zlbkcpA
# Inserted/updated video hJlY2BfhJj8
# Inserted/updated video s5Gv2-a7r60
# Inserted/updated video 2ifcYSRC9q0
# Inserted/updated video 0AeQonKeCcs
# Inserted/updated video p-Hx8ncC0zA
# Inserted/updated video d23cXBONxWg
# Inserted/updated video LmEDVV4TMkc
# Inserted/updated video KLQCMQkkzvA
# Inserted/updated video wjEIu3b9F70
# Inserted/updated video uiQbqDfGWVg
# Inserted/updated video oQnsD5RXE6o
# Inserted/updated video EvZ9j47NphM
# Inserted/updated video DuZdzVv74pY
# Inserted/updated video wiFZYtCxvqI
# Inserted/updated video rPUq-j521EU
# Inserted/updated video 8UbEqoNSqYA
# Inserted/updated video 3rsmUuq4hNk
# Inserted/updated video 0ckVrhiI2gA
# Inserted/updated video yMUnJ9bwcL8
# Inserted/updated video sDyZ9ziGiLM
# Inserted/updated video qwA45Rt3R3A
# Inserted/updated video sjutpaJkOy8
# Inserted/updated video DxSQUOPeWJ4
# Inserted or updated playlist UU58aOfdkdPKu0na-1hi5d6w
# Inserted/updated video qcxg_Sgroo8
# Inserted/updated video l0PD-TnGFVo
# Inserted/updated video -Y6W16afKKQ
# Inserted/updated video hM42qNi2rxs
# Inserted/updated video QCsi3Em3jak
# Inserted/updated video 8aUPnvunkHc
# Inserted/updated video feSuar-NbOI
# Inserted/updated video R8336zpqWEU
# Inserted/updated video xOQ3UG6hi6I
# Inserted/updated video YZ9oMqGEB30
# Inserted/updated video KYfErPIi0xI
# Inserted/updated video sL3YOQgVVac
# Inserted/updated video rbteyMJUsSU
# Inserted/updated video rYSjEjxx9VQ
# Inserted/updated video -3AcN6AefXM
# Inserted or updated playlist UULH5ojAg1XIyxcOCazK4n-Q
# Inserted/updated video AbS6VUO6rbo
# Inserted/updated video KWNXqOdckKk
# Inserted/updated video Cb0n9gTuc6k
# Inserted or updated playlist UUeMdpc7DBqGS58shLa7DOYg
# Inserted/updated video hOxuVBL3qJA
# Inserted/updated video 0pruWFQLfiE
# Inserted/updated video igTApX_9s4w
# Inserted/updated video OsVEIYi2hQ4
# Inserted/updated video y6AQ9_qxrkA
# Inserted/updated video qYalRVVpdcQ
# Inserted/updated video 1ZzzKHUXUOc
# Inserted/updated video IXlkuTh7Lus
# Inserted/updated video IdbLv3NyNu4
# Inserted/updated video EzKbW-qHPmQ
# Inserted/updated video Gng7tJhtidw
# Inserted/updated video 8jH9ceve8aE
# Inserted/updated video oPPn4gNWfNQ
# Inserted/updated video -HBnSeS8fO8
# Inserted/updated video Wr7f_0XFjYo
# Inserted/updated video Rachxj3Q1xo
# Inserted/updated video rJSufw1LDmE
# Inserted/updated video AZs9n9Adxyk
# Inserted/updated video qW_iHZ-3Z40
# Inserted/updated video 2ek8KbvcTwk
# Inserted/updated video 9Ed81HHGPQU
# Inserted/updated video a3rsB58fcTc
# Inserted/updated video CJPOybvNNiE
# Inserted/updated video NZCH87o_S3o
# Inserted/updated video Wt71UNuWtNM
# Inserted/updated video 3kMLWrwWZyk
# Inserted/updated video 7PnHEi3jXzc
# Inserted/updated video _l3V0yvZw_c
# Inserted/updated video bO4sY6tiSIk
# Inserted/updated video xSC3LHh_a9g
# Inserted/updated video lC2avaCWokI
# Inserted/updated video Qa1NJx5Qn-8
# Inserted/updated video ZI1z1e3DpLI
# Inserted/updated video StiSPu3fNAs
# Inserted/updated video ttCbnyC8f3M
# Inserted/updated video -neraz2yAhM
# Inserted/updated video HiSsEp-zHTs
# Inserted/updated video ZIYISLPDoTY
# Inserted/updated video Rbj5aBvRZD0
# Inserted/updated video 6imcj_eewcU
# Inserted/updated video 16PgRSAqjkc
# Inserted/updated video cj6wzVrgNww
# Inserted/updated video nPePCf36idE
# Inserted/updated video KCVGm58r7A8
# Inserted/updated video QR3pH-SHTYM
# Inserted/updated video CzzAY8l3LpQ
# Inserted/updated video NFqrvkbhsAI
# Inserted/updated video HHF9_YfFj6A
# Inserted/updated video gYs7qKfhTsg
# Inserted/updated video AZ-s0C7lnPE
# Inserted or updated playlist UUmmsAsZx40YSA_aBKKNQtBQ
# Inserted/updated video NKA8EMtLxS0
# Inserted/updated video Kj4lne80kJ4
# Inserted/updated video S38jA79loGs
# Processing video: acQrarQ9PIo
 'comment_published_date': '2021-11-22T08:40:42Z'}, {'comment_id': 'UgyPsYUdWX_y-Uw2WDh4AaABAg', 'comment_text': 'Please can you share the notes please', 'comment_author': '@sangeethap4181', 'comment_published_date': '2021-08-12T18:42:19Z'}, {'comment_id': 'Ugxqv9Nv3pGLmgplZ8h4AaABAg', 'comment_text': 'Bro can make tutorial of this please bro', 'comment_author': '@rajeshwarikg4', 'comment_published_date': '2021-08-06T14:09:10Z'}, {'comment_id': 'UgzlAQpbEqT-MJ7v_Sl4AaABAg', 'comment_text': 'It’s amazing bro', 'comment_author': '@rajeshwarikg4', 'comment_published_date': '2021-08-06T14:08:12Z'}, {'comment_id': 'UgxjGsm9RBX9-j72duh4AaABAg', 'comment_text': 'Good job👏👏', 'comment_author': '@hemamukundan9961', 'comment_published_date': '2021-07-09T04:09:44Z'}, {'comment_id': 'UgzkKyvrzfsDhXiebKN4AaABAg', 'comment_text': 'Nice one nk tunes keep rocking 👍', 'comment_author': '@monishgarun', 'comment_published_date': '2021-06-28T12:25:59Z'}, {'comment_id': 'UgwMwKGMhjk0j2AeYvh4AaABAg', 'comment_text': 'Really too good 👌👌', 'comment_author': '@anvitashindhe263', 'comment_published_date': '2021-06-23T20:20:27Z'}, {'comment_id': 'UgzzDzAbK3K3w2wILi54AaABAg', 'comment_text': '👌🏻👌🏻', 'comment_author': '@kokilavenkatram8832', 'comment_published_date': '2021-06-23T14:35:56Z'}, {'comment_id': 'UgytlEAopE7FsMFpWcl4AaABAg', 'comment_text': 'Super broo👌🏻👏🏻', 'comment_author': '@user-os9tu9gh5s', 'comment_published_date': '2021-06-23T03:23:50Z'}]
# Inserted/Updated comment UgwQNyTTJlPZFBhpaMp4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgyLfVS0sf5thcLWOil4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgwFeXS1NWk3eytj8zV4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgzWmbwni1uC9e7-x0F4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgzHBlmeKtX00U-ZIZJ4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgyPsYUdWX_y-Uw2WDh4AaABAg for video FkOL_uySa20
# Inserted/Updated comment Ugxqv9Nv3pGLmgplZ8h4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgzlAQpbEqT-MJ7v_Sl4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgxjGsm9RBX9-j72duh4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgzkKyvrzfsDhXiebKN4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgwMwKGMhjk0j2AeYvh4AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgzzDzAbK3K3w2wILi54AaABAg for video FkOL_uySa20
# Inserted/Updated comment UgytlEAopE7FsMFpWcl4AaABAg for video FkOL_uySa20
# Processing video: EE7mHmpKddw
# Comments for video EE7mHmpKddw: []
# Processing video: nteaQoj3mJw
# Comments for video nteaQoj3mJw: []
# Processing video: 4Gakw4llegA
AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgwChSBzrOnb46BiNjN4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgyxITJFxOHcS-1SCTF4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgzRoFJgFDdLGzmd9mZ4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgwdzonrSBxPf_cDFNF4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgwwN0A7Q58ros1Yztt4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgztB3jZp8Av1ie15eB4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgwzUBXsbQ_xfHALtRB4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgwM2MmksFypI0OqMD54AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgzpE7MKMAVj3ucDmYN4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment Ugyj-Hkr4j-_oL4_XTJ4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgyFCWPk2osM6PTykwp4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment Ugxu-94HubHyNwSocGF4AaABAg for video JdyZ-ek67bI
# Inserted/Updated comment UgzYqK9WcnnK1cRFAy14AaABAg for video JdyZ-ek67bI
# Processing video: jzpoKhGC_OM
# Comments for video jzpoKhGC_OM: [{'comment_id': 'Ugy30jd5sxOI5PCSQrd4AaABAg', 'comment_text': 'Anna retail sales forecast ku neega vaerum jupiter notebook dha potrikeega,adhuku user interface vaenama anna .vaerum notebook kaamicha moduma .nanum en final project pannanum adha na kaekuraee', 'comment_author': '@pretisherine6025', 'comment_published_date': '2024-05-29T01:56:48Z'}, {'comment_id': 'UgzGwHoeRBlPsiRMw8B4AaABAg', 'comment_text': 'Anna unga final guvi project enna anna???', 'comment_author': '@pretisherine6025', 'comment_published_date': '2024-05-28T14:58:23Z'}, {'comment_id': 'UgyT7c_H_-S-1Lcs1pF4AaABAg', 'comment_text': 'Bro this is the last video of this project.', 'comment_author': '@nethraswami9457', 'comment_published_date': '2024-04-09T10:18:01Z'}, {'comment_id': 'UgzMZvkuuFVQqcZA0894AaABAg', 'comment_text': 'why cant we update the values bro instead of deletion and insertion', 'comment_author': '@madhusankar9671', 'comment_published_date': '2024-04-07T13:22:11Z'}, {'comment_id': 'UgxFc3x-6lSm315B8Bp4AaABAg', 'comment_text': 'Anna some errors for YouTube project so please help anna', 'comment_author': '@umaiyaumaiya9397', 'comment_published_date': '2024-03-27T11:10:32Z'}, {'comment_id': 'Ugzq8nWp7sNM35EB0Kd4AaABAg', 'comment_text': 'Bro have u got selected in placement', 'comment_author': '@deeparajendran3457', 'comment_published_date': '2024-03-27T09:11:25Z'}]
# Inserted/Updated comment Ugy30jd5sxOI5PCSQrd4AaABAg for video jzpoKhGC_OM
# Inserted/Updated comment UgzGwHoeRBlPsiRMw8B4AaABAg for video jzpoKhGC_OM
# Inserted/Updated comment UgyT7c_H_-S-1Lcs1pF4AaABAg for video jzpoKhGC_OM
# Inserted/Updated comment UgzMZvkuuFVQqcZA0894AaABAg for video jzpoKhGC_OM
# Inserted/Updated comment UgxFc3x-6lSm315B8Bp4AaABAg for video jzpoKhGC_OM
# Inserted/Updated comment Ugzq8nWp7sNM35EB0Kd4AaABAg for video jzpoKhGC_OM
# Processing video: be97AndjHCM
# Comments for video be97AndjHCM: [{'comment_id': 'Ugw6SKs8bVaaGXMvzPl4AaABAg', 'comment_text': 'Bro next videos podunga bro', 'comment_author': '@stark2794', 'comment_published_date': '2024-03-26T11:01:28Z'}, {'comment_id': 'UgzKcox2DFEjiw-tzEF4AaABAg', 'comment_text': 'Bro upload next videos', 'comment_author': '@chethanb7833', 'comment_published_date': '2024-03-25T07:26:07Z'}, {'comment_id': 'UgwMfadms2qWp6li3cZ4AaABAg', 'comment_text': 'Let us know how to run this in mysql', 'comment_author': '@haariss4820', 'comment_published_date': '2024-03-23T18:04:11Z'}, {'comment_id': 'UgzBKeqUer_KC1qMKmZ4AaABAg', 'comment_text': 'Bro inno evlo videos iruku', 'comment_author': '@stark2794', 'comment_published_date': '2024-03-23T16:47:52Z'}, {'comment_id': 'Ugx4Dhajm1qHDu5O0Zx4AaABAg', 'comment_text': 'great brother, great teaching skills', 'comment_author': '@qwertypad123', 'comment_published_date': '2024-03-23T01:29:34Z'}]
# Inserted/Updated comment Ugw6SKs8bVaaGXMvzPl4AaABAg for video be97AndjHCM
# Inserted/Updated comment UgzKcox2DFEjiw-tzEF4AaABAg for video be97AndjHCM
# Inserted/Updated comment UgwMfadms2qWp6li3cZ4AaABAg for video be97AndjHCM
# Inserted/Updated comment UgzBKeqUer_KC1qMKmZ4AaABAg for video be97AndjHCM
# Inserted/Updated comment Ugx4Dhajm1qHDu5O0Zx4AaABAg for video be97AndjHCM
# Processing video: uAqwxNaaMtg
# Comments for video uAqwxNaaMtg: [{'comment_id': 'Ugwtzj1dJY2S4QuPA3J4AaABAg', 'comment_text': 'Y bre we r using sqlite3 instead of mysql or pycerg?', 'comment_author': '@haariss4820', 'comment_published_date': '2024-03-21T10:55:35Z'}, {'comment_id': 'UgxDiniuB_CouaYKMXZ4AaABAg', 'comment_text': 'Bro background color change in streamlit app.', 'comment_author': '@prithiviraj6598', 'comment_published_date': '2024-03-21T10:30:11Z'}]
# Inserted/Updated comment Ugwtzj1dJY2S4QuPA3J4AaABAg for video uAqwxNaaMtg
# Inserted/Updated comment UgxDiniuB_CouaYKMXZ4AaABAg for video uAqwxNaaMtg
# Processing video: GGDAZj-xXnw
# Comments for video GGDAZj-xXnw: [{'comment_id': 'Ugz4Nn21A5NR3fqlQNp4AaABAg', 'comment_text': 'Bro stramlit background color change panna mudiyumvaa', 'comment_author': '@prithiviraj6598', 'comment_published_date': '2024-03-20T04:13:35Z'}]
# Inserted/Updated comment Ugz4Nn21A5NR3fqlQNp4AaABAg for video GGDAZj-xXnw
# Processing video: 9rFODpR2pc8
# Comments for video 9rFODpR2pc8: [{'comment_id': 'UgwdoezCkl5Pv6WIviV4AaABAg', 'comment_text': 'Sir file uploader mattum Vara matikithu', 'comment_author': '@idhazh', 'comment_published_date': '2024-04-25T06:15:13Z'}, {'comment_id': 'UgxpTQ629YX-fPBs6pV4AaABAg', 'comment_text': 'Thank you bro', 'comment_author': '@mperumal726', 'comment_published_date': '2024-03-20T07:23:36Z'}]
# Inserted/Updated comment UgwdoezCkl5Pv6WIviV4AaABAg for video 9rFODpR2pc8
# Inserted/Updated comment UgxpTQ629YX-fPBs6pV4AaABAg for video 9rFODpR2pc8
# Processing video: J-B2uxGujwc
# Comments for video J-B2uxGujwc: [{'comment_id': 'UgwAXhoqirmC6uTbzy94AaABAg', 'comment_text': 'Thank you bro', 'comment_author': '@mperumal726', 'comment_published_date': '2024-03-20T01:57:34Z'}]
, {'comment_id': 'Ugx9b1rUEtsKPF8CXuF4AaABAg', 'comment_text': 'Thanks bro', 'comment_author': '@mperumal726', 'comment_published_date': '2024-03-18T13:33:31Z'}, {'comment_id': 'UgxjF3mzzzATNCT779l4AaABAg', 'comment_text': 'Kojam fasta poduga bro', 'comment_author': '@baraneetharanr5916', 'comment_published_date': '2024-03-18T10:35:32Z'}, {'comment_id': 'Ugx7SRp08VUjd1OIAAJ4AaABAg', 'comment_text': 'Ithu evlo video bro varum', 'comment_author': '@stark2794', 'comment_published_date': '2024-03-18T07:04:15Z'}]
# Inserted/Updated comment Ugy8UsbZ6UeFYORLFuJ4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment UgxAulvW-4ccu4x7hSV4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment Ugyv4A-weGwZGqSh_o14AaABAg for video Qftj5XU133Q
# Inserted/Updated comment Ugw53iqf6Bm5uLBwymx4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment UgzwnefZM0Dn1Yb-3e54AaABAg for video Qftj5XU133Q
# Inserted/Updated comment UgzOTpJKxxWxErzO3dZ4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment UgysH4tdamqNZs7R1up4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment UgwKgoqupPmf_DcgfAt4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment Ugx9b1rUEtsKPF8CXuF4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment UgxjF3mzzzATNCT779l4AaABAg for video Qftj5XU133Q
# Inserted/Updated comment Ugx7SRp08VUjd1OIAAJ4AaABAg for video Qftj5XU133Q
# Processing video: PPbIg3nLArk
# Comments for video PPbIg3nLArk: [{'comment_id': 'Ugz2DOzZ1OVfG6S6o7V4AaABAg', 'comment_text': '&quot;&#39;Airbnb&#39; திட்டத்தை தொடக்க முடியுமா?&quot;', 'comment_author': '@sgigadsgigad4019', 'comment_published_date': '2024-03-16T14:42:37Z'}, {'comment_id': 'UgxOghMcyLM4Tr1mY7d4AaABAg', 'comment_text': 'Pls post video&#39;s  bro', 'comment_author': '@user-my4ut5oc4w', 'comment_published_date': '2024-03-16T11:23:28Z'}, {'comment_id': 'UgyVo4hirEBLyGM0sAd4AaABAg', 'comment_text': 'Bro please post videos', 'comment_author': '@user-my4ut5oc4w', 'comment_published_date': '2024-03-16T11:22:46Z'}]
# Inserted/Updated comment Ugz2DOzZ1OVfG6S6o7V4AaABAg for video PPbIg3nLArk
# Inserted/Updated comment UgxOghMcyLM4Tr1mY7d4AaABAg for video PPbIg3nLArk
# Inserted/Updated comment UgyVo4hirEBLyGM0sAd4AaABAg for video PPbIg3nLArk
# Processing video: 3ELkF2mrJGQ
# Comments for video 3ELkF2mrJGQ: [{'comment_id': 'UgyvZBC-_r454SyFX914AaABAg', 'comment_text': 'Thanks a lot Bro .I completed this project only bcos of you. Thank you so much for your guidance and clear explanation.', 'comment_author': '@ramyamahesh5321', 'comment_published_date': '2024-05-31T07:52:38Z'}, {'comment_id': 'UgwiAi0BZ19eAy2dtbd4AaABAg', 'comment_text': 'Hi bro, extraordinary explanation... yepdi bro ivlo lines azhaga yezhudi explain panringa<br>neenga explain panradhu yellame clean ah puridhu bro aana yenaka sondama yezhuda therila na... ungala pathu yenakum kathukanum nu aasaiya iruku...', 'comment_author': '@sriramsridhar303', 'comment_published_date': '2024-05-16T14:01:58Z'}, {'comment_id': 'UgzkIAMgZ6vIBx3I7JB4AaABAg', 'comment_text': 'how to change the background colour and font family bro?<br><br>even though i have styled it using st.markdown, it is not reflecting.', 'comment_author': '@madhusankar9671', 'comment_published_date': '2024-04-03T16:15:58Z'}]
# Inserted/Updated comment UgyvZBC-_r454SyFX914AaABAg for video 3ELkF2mrJGQ
# Inserted/Updated comment UgwiAi0BZ19eAy2dtbd4AaABAg for video 3ELkF2mrJGQ
# Inserted/Updated comment UgzkIAMgZ6vIBx3I7JB4AaABAg for video 3ELkF2mrJGQ
# Processing video: 1DJDLibr3Xw
# Comments for video 1DJDLibr3Xw: [{'comment_id': 'Ugx9J8CE8r0HfPrdyZl4AaABAg', 'comment_text': 'can you start guvi airbnb project bro ?', 'comment_author': '@sgigadsgigad4019', 'comment_published_date': '2024-03-13T13:41:44Z'}, {'comment_id': 'UgzvvCJ-wYxkc33dNk54AaABAg', 'comment_text': 'what happened bro , home page code ?', 'comment_author': '@sgigadsgigad4019', 'comment_published_date': '2024-03-13T13:41:21Z'}, {'comment_id': 'Ugw4Chh1i_ugpIaD-k54AaABAg', 'comment_text': 'Bro enum videos irruka', 'comment_author': '@ramersaranya4177', 'comment_published_date': '2024-03-10T01:33:08Z'}]
# Inserted/Updated comment Ugx9J8CE8r0HfPrdyZl4AaABAg for video 1DJDLibr3Xw
# Inserted/Updated comment UgzvvCJ-wYxkc33dNk54AaABAg for video 1DJDLibr3Xw
# Inserted/Updated comment Ugw4Chh1i_ugpIaD-k54AaABAg for video 1DJDLibr3Xw
# Processing video: 65VTeSuYyps
# Comments for video 65VTeSuYyps: []
# Processing video: ZTNnojP6QE4
# Comments for video ZTNnojP6QE4: [{'comment_id': 'UgwjnsMMnyxuZNORjpt4AaABAg', 'comment_text': 'Bro aggregate insurance mattu tha show aaguthu balance are not showing', 'comment_author': '@mahadevanarunachalam3157', 'comment_published_date': '2024-03-12T10:04:26Z'}]
# Inserted/Updated comment UgwjnsMMnyxuZNORjpt4AaABAg for video ZTNnojP6QE4
# Processing video: ty7D_X1Dn18
# Comments for video ty7D_X1Dn18: [{'comment_id': 'UgwEwI6bKwsmBFXWjb54AaABAg', 'comment_text': 'Na atha 10 question soldra', 'comment_author': '@DatascientistH', 'comment_published_date': '2024-04-07T06:59:34Z'}, {'comment_id': 'UgxScA_qYDsRZUVyvCp4AaABAg', 'comment_text': 'Bro question vathu mentor tharuvakala eilla nama own na bro', 'comment_author': '@DatascientistH', 'comment_published_date': '2024-04-07T06:58:59Z'}, {'comment_id': 'UgxGYk3lwkhzYnMVFI54AaABAg', 'comment_text': 'Bro Monday live evaluation', 'comment_author': '@DatascientistH', 'comment_published_date': '2024-04-06T10:49:43Z'}, {'comment_id': 'UgyTQTzqfoZIEDEp1aV4AaABAg', 'comment_text': 'Pls say this bro', 'comment_author': '@DatascientistH', 'comment_published_date': '2024-04-06T10:35:20Z'}, {'comment_id': 'UgwmtDUMZRE8lciSF4x4AaABAg', 'comment_text': 'Bro where I find questions bro pls tell me', 'comment_author': '@DatascientistH', 'comment_published_date': '2024-04-06T10:34:26Z'}]
# Inserted/Updated comment UgwEwI6bKwsmBFXWjb54AaABAg for video ty7D_X1Dn18
# Inserted/Updated comment UgxScA_qYDsRZUVyvCp4AaABAg for video ty7D_X1Dn18
# Inserted/Updated comment UgxGYk3lwkhzYnMVFI54AaABAg for video ty7D_X1Dn18
# Inserted/Updated comment UgyTQTzqfoZIEDEp1aV4AaABAg for video ty7D_X1Dn18
# Inserted/Updated comment UgwmtDUMZRE8lciSF4x4AaABAg for video ty7D_X1Dn18
# Processing video: 2YhFIbhGzGk
# Comments for video 2YhFIbhGzGk: [{'comment_id': 'Ugyfr1d4AIshXwWzGjV4AaABAg', 'comment_text': 'I anna MongoDB use pannama code eludha mudemana possible ha na', 'comment_author': '@vinithav9846', 'comment_published_date': '2024-04-30T11:14:17Z'}, {'comment_id': 'Ugw5OU_iL1pmk4bVQVB4AaABAg', 'comment_text': 'How to slove ssl handsake failed error', 'comment_author': '@sudarshank2575', 'comment_published_date': '2024-03-29T11:04:38Z'}, {'comment_id': 'UgzOEu7dXvYHeUpmsoZ4AaABAg', 'comment_text': 'so much of errors are there<br>in this', 'comment_author': '@mahenderragamshetti8102', 'comment_published_date': '2024-03-20T21:04:23Z'}, {'comment_id': 'Ugzn_95TGl4mQi_ovmp4AaABAg', 'comment_text': 'nice bro i love your explaintion', 'comment_author': '@siranjeeviv2563', 'comment_published_date': '2024-03-20T16:32:28Z'}, {'comment_id': 'Ugwm_D_XcCDqi8p9IMN4AaABAg', 'comment_text': 'hi bro', 'comment_author': '@user-mk9vv3zd6n', 'comment_published_date': '2024-03-11T10:44:38Z'}]
# Inserted/Updated comment Ugyfr1d4AIshXwWzGjV4AaABAg for video 2YhFIbhGzGk
# Inserted/Updated comment Ugw5OU_iL1pmk4bVQVB4AaABAg for video 2YhFIbhGzGk
# Inserted/Updated comment UgzOEu7dXvYHeUpmsoZ4AaABAg for video 2YhFIbhGzGk
# Inserted/Updated comment Ugzn_95TGl4mQi_ovmp4AaABAg for video 2YhFIbhGzGk
# Inserted/Updated comment Ugwm_D_XcCDqi8p9IMN4AaABAg for video 2YhFIbhGzGk
# Processing video: SYQETrGd4bo
# Comments for video SYQETrGd4bo: [{'comment_id': 'UgyTVeZvwqJ_NMAkTVp4AaABAg', 'comment_text': 'your great bro needs more videos like this', 'comment_author': '@SarathKumar-ru1zh', 'comment_published_date': '2024-06-03T17:51:14Z'}, {'comment_id': 'UgxM3f24oiE7O-ktkQx4AaABAg', 'comment_text': 'We can raise them query bro', 'comment_author': '@deeparajendran3457', 'comment_published_date': '2024-03-10T01:04:10Z'}, {'comment_id': 'UgyiySkbFyXnrNO1tMB4AaABAg', 'comment_text': 'hi bro my dead line of this project is 8-3-24 , i agree with your point but  what is my point of view is  they didn&#39;t even guid me with this project  tho am new to this stream am a non it person so it very difficult do this kinda project in after class started just one month  . even you faced these same thing or how could i help with this, should i have to contact guvi for help or this is how they behave', 'comment_author': '@rishiraja1630', 'comment_published_date': '2024-03-07T09:21:45Z'}]
# Inserted/Updated comment UgyTVeZvwqJ_NMAkTVp4AaABAg for video SYQETrGd4bo
# Inserted/Updated comment UgxM3f24oiE7O-ktkQx4AaABAg for video SYQETrGd4bo
# Inserted/Updated comment UgyiySkbFyXnrNO1tMB4AaABAg for video SYQETrGd4bo
# Processing video: d62FsKPzV-M
# Comments for video d62FsKPzV-M: [{'comment_id': 'Ugy_k-BfwxA5LXiIGTh4AaABAg', 'comment_text': 'hi bro. for me its showing like one positional arguement missing in tables() function. can u help me in this?', 'comment_author': '@HariharanNandagopal', 'comment_published_date': '2024-04-27T14:35:59Z'}, {'comment_id': 'UgwoAjl72rVUHvGSzdx4AaABAg', 'comment_text': 'bro can you start airbnb or singapore ........... guvi project after phonepe , please upload 2 to 3 videos daily so that we can learn and finish the projects as soon as possible', 'comment_author': '@sgigadsgigad4019', 'comment_published_date': '2024-03-07T05:25:47Z'}]
# Inserted/Updated comment Ugy_k-BfwxA5LXiIGTh4AaABAg for video d62FsKPzV-M
# Inserted/Updated comment UgwoAjl72rVUHvGSzdx4AaABAg for video d62FsKPzV-M
# Processing video: hzCkDbyToCA
# Comments for video hzCkDbyToCA: [{'comment_id': 'Ugzj7wrxUTqr_-wUYfB4AaABAg', 'comment_text': 'thala enga poiteenga romba nala, adutha adutha project panni video podunga, usefull uh iruku', 'comment_author': '@qwertypad123', 'comment_published_date': '2024-03-16T02:35:46Z'}, {'comment_id': 'UgwaTBrCNdOeZRsQytV4AaABAg', 'comment_text': 'Sir<br>Great video and great efforts needed to bring this. Very useful.', 'comment_author': '@vasutke1187', 'comment_published_date': '2024-03-07T00:11:30Z'}]
# Inserted/Updated comment Ugzj7wrxUTqr_-wUYfB4AaABAg for video hzCkDbyToCA
# Inserted/Updated comment UgwaTBrCNdOeZRsQytV4AaABAg for video hzCkDbyToCA
# Processing video: deEG8VCxmFQ
# Comments for video deEG8VCxmFQ: [{'comment_id': 'UgzoPNGLp-QYKZHhqlx4AaABAg', 'comment_text': 'Hi bro first of all thank u so much.pls start Airbnb project,pls bro😊', 'comment_author': '@murugalakshmiram5582', 'comment_published_date': '2024-06-04T14:57:43Z'}, {'comment_id': 'Ugy5hAOveM-ObrxnXY54AaABAg', 'comment_text': 'bro can you start airbnb or singapore ........... guvi project after phonepe , please upload 2 to 3 videos daily so that we can learn and finish the projects as soon as possible', 'comment_author': '@sgigadsgigad4019', 'comment_published_date': '2024-03-07T05:27:10Z'}]
# Inserted/Updated comment UgzoPNGLp-QYKZHhqlx4AaABAg for video deEG8VCxmFQ
# Inserted/Updated comment Ugy5hAOveM-ObrxnXY54AaABAg for video deEG8VCxmFQ
# Processing video: Q13Ab3J9JXU
# Comments for video Q13Ab3J9JXU: []
# Processing video: tadK65KehvA
# Comments for video tadK65KehvA: [{'comment_id': 'UgxrzQCaYePSvIJ32FJ4AaABAg', 'comment_text': 'Enna poite iruku😂. Ithuku illaya sir oru endu', 'comment_author': '@stark2794', 'comment_published_date': '2024-03-01T17:28:20Z'}]
# Inserted/Updated comment UgxrzQCaYePSvIJ32FJ4AaABAg for video tadK65KehvA
# Processing video: HoX7T7BsqAs
# Comments for video HoX7T7BsqAs: []
# Processing video: bbbi0RAMrZo
# Comments for video bbbi0RAMrZo: []
# Processing video: D0pWDo0x5ao
# Comments for video D0pWDo0x5ao: [{'comment_id': 'UgwDeN68e0RLDdUlo1Z4AaABAg', 'comment_text': 'bro in aggregated insurance only 4th quarter json file loaded in dataframe, others don&#39;t. how to rectify this.', 'comment_author': '@suryakarthik87', 'comment_published_date': '2024-06-19T19:42:19Z'}, {'comment_id': 'UgxdBUniFgOiyJTgnR94AaABAg', 'comment_text': 'bro app opens la bar chart show agala help pana mudiyuma?      <br>    def map_user_plot_3(df, states):\r<br>    muyqs= df[df[&quot;States&quot;] == states]\r<br>    muyqs.reset_index(drop= True, inplace=True)\r<br>\r<br>    col1,col2 = st.columns(2)\r<br>    with col1:\r<br>\r<br>        fig_map_user_bar_1= px.bar(muyqs, x=&quot;RegisteredUsers&quot;, y=&quot;Districts&quot;,orientation= &quot;h&quot;,\r<br>                                title= f&quot;{states.upper()} REGISTERED USERS&quot;, height= 800, color_discrete_sequence= px.colors.sequential.Pinkyl_r)\r<br>\r<br>        st.plotly_chart(fig_map_user_bar_1)\r<br>    \r<br>    with col2:\r<br>\r<br>        fig_map_user_bar_2= px.bar(muyqs, x=&quot;AppOpens&quot;, y=&quot;Districts&quot;,orientation= &quot;h&quot;,\r<br>                                title= f&quot;{states.upper()} APPOPENS&quot;, height= 800, color_discrete_sequence= px.colors.sequential.Pinkyl)\r<br>\r<br>        st.plotly_chart(fig_map_user_bar_2)', 'comment_author': '@rsaakash5640', 'comment_published_date': '2024-06-13T16:29:48Z'}, {'comment_id': 'UgxisUnOesMU7kvvcF54AaABAg', 'comment_text': 'Bro how to download <a href="http://st.video/">st.video</a> file', 'comment_author': '@phoorneshmurali6441', 'comment_published_date': '2024-03-01T13:38:33Z'}]
# Inserted/Updated comment UgwDeN68e0RLDdUlo1Z4AaABAg for video D0pWDo0x5ao
# Inserted/Updated comment UgxdBUniFgOiyJTgnR94AaABAg for video D0pWDo0x5ao
# Inserted/Updated comment UgxisUnOesMU7kvvcF54AaABAg for video D0pWDo0x5ao
# Processing video: hdOny_O8Qxg
# Comments for video hdOny_O8Qxg: [{'comment_id': 'Ugz-2y4jCvweQsJJe_F4AaABAg', 'comment_text': '<a href="https://www.youtube.com/watch?v=hdOny_O8Qxg&amp;t=802">13:22</a> there is an error at my code while viewing in streamlit = &#39;NoneType&#39; object is not subscriptable  what to do?', 'comment_author': '@elixrishi7816', 'comment_published_date': '2024-04-15T15:03:39Z'}]
# Inserted/Updated comment Ugz-2y4jCvweQsJJe_F4AaABAg for video hdOny_O8Qxg
# Processing video: gdNrhpiaMqk
# Comments for video gdNrhpiaMqk: [{'comment_id': 'UgyGTl31fDDUxZGrcr54AaABAg', 'comment_text': 'Thank u sir', 'comment_author': '@sureshk-qn7ox', 'comment_published_date': '2024-04-22T05:24:03Z'}]
# Inserted/Updated comment UgyGTl31fDDUxZGrcr54AaABAg for video gdNrhpiaMqk
# Processing video: wLrzbanUVKs
# Comments for video wLrzbanUVKs: [{'comment_id': 'Ugy_qTQBRz7mu25DSn14AaABAg', 'comment_text': 'bro numpy,pandas and matplotlib seaborn vachi oru end to end video podunga bro', 'comment_author': '@pubgclutch7719', 'comment_published_date': '2024-02-28T14:01:45Z'}]
# Inserted/Updated comment Ugy_qTQBRz7mu25DSn14AaABAg for video wLrzbanUVKs
# Processing video: VOxOJMlpbw0
# Comments for video VOxOJMlpbw0: [{'comment_id': 'UgyLQzd5vA5La9KeFMV4AaABAg', 'comment_text': 'Bro please unga mail id kedaikuma bcoz I am also in guvi that&#39;s why', 'comment_author': '@stark2794', 'comment_published_date': '2024-02-27T19:23:09Z'}, {'comment_id': 'Ugyd44dGf5MZPKdf0dV4AaABAg', 'comment_text': 'Hi Vignesh I still have doubt in YouTube data harvesting in that after installing googleapiclient . From googleapiclient.discovery is not working showing error like no module name googleapiclient ! Am confused ! Can you help me in this . Can you drop you’re email so I could contact you for this doubts', 'comment_author': '@rishiraja1630', 'comment_published_date': '2024-02-27T10:14:21Z'}]
# Inserted/Updated comment UgyLQzd5vA5La9KeFMV4AaABAg for video VOxOJMlpbw0
# Inserted/Updated comment Ugyd44dGf5MZPKdf0dV4AaABAg for video VOxOJMlpbw0
# Processing video: ZaWHSsqo2Fw
# Comments for video ZaWHSsqo2Fw: [{'comment_id': 'UgyK58HHaSv6B5ZPldt4AaABAg', 'comment_text': 'enakku &quot;There are multiple identical st.slider widgets with the same generated key.&quot; nu katudhu', 'comment_author': '@danvathdarshan1426', 'comment_published_date': '2024-05-22T19:36:02Z'}, {'comment_id': 'UgyxmX70z2FLme75lM54AaABAg', 'comment_text': 'Hi bro,<br>When I pass map insurance through the year function all the states graphs and geo maps are showing at max. Can you help me resolve this issue ?', 'comment_author': '@safathali-jp3ty', 'comment_published_date': '2024-05-20T16:32:23Z'}]
# Inserted/Updated comment UgyK58HHaSv6B5ZPldt4AaABAg for video ZaWHSsqo2Fw
# Inserted/Updated comment UgyxmX70z2FLme75lM54AaABAg for video ZaWHSsqo2Fw
# Processing video: VKySXPjmUzo
# ...
# Inserted/Updated comment Ugw7eH4aPUzh5-qeGHx4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment UgzRpHvWZNbd1hW9cOB4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment Ugyq0iHk-QGkTJGT_4F4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment Ugw16nroi0aaQA4qFHh4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment Ugx_fwMM67x5H4-QYkp4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment UgwfRLaS3gS5380POJl4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment UgySiAKws-t-zcBKSNF4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment UgyN4ETJevKFNHMRuCV4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment UgxQqBQmtmeg4UwOQl54AaABAg for video a3rsB58fcTc
# Inserted/Updated comment Ugzi0Il0cmtYE7XB7Jt4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment UgylaxojYn8RBlGBeWJ4AaABAg for video a3rsB58fcTc
# Inserted/Updated comment Ugx_lNu3N9UUdAalh9Z4AaABAg for video a3rsB58fcTc
# Inserted/Updated com
AaABAg for video CJPOybvNNiE
# Inserted/Updated comment UgyltaONaKjp58pjTbx4AaABAg for video CJPOybvNNiE
# Inserted/Updated comment Ugz6TekPwtE-W4ODwuF4AaABAg for video CJPOybvNNiE
# Inserted/Updated comment UgzP8Pfn-JNHK1B6syl4AaABAg for video CJPOybvNNiE
# Inserted/Updated comment UgzdIKPcOZN0YlBSawZ4AaABAg for video CJPOybvNNiE
# Inserted/Updated comment UgxeeJPsRqcbusZbtYZ4AaABAg for video CJPOybvNNiE
# Inserted/Updated comment UgyDwLOIqSdpMtbJfr14AaABAg for video CJPOybvNNiE
# Inserted/Updated comment Ugz9T8pdbI7BcGVqXId4AaABAg for video CJPOybvNNiE
# Inserted/Updated comment UgzcLq4wGRu-NInCDI94AaABAg for video CJPOybvNNiE
# Inserted/Updated comment UgzBykLZWbvSeZxqDcR4AaABAg for video CJPOybvNNiE
# Processing video: NZCH87o_S3o
# Comments for video NZCH87o_S3o: [{'comment_id': 'Ugyc5oqYrtLUcHLCQQB4AaABAg', 'comment_text': '😂Dhdfbfkfrrrdffhirryfdeyhrhn🎉😢😅', 'comment_author': '@valecianta9487', 'comment_published_date': '2024-01-20T17:41:22Z'}, {'comment_id': 'UgyGxOEJR5kvD-aBSYF4AaABAg', 'comment_text': 'Funny, hilarious and priceless. Reminds me of how much an animal can brighten even the darkest of days!!!!', 'comment_author': '@loonieoliver5195', 'comment_published_date': '2024-01-17T14:47:55Z'}, {'comment_id': 'UgyR_rriPIMFiO5LxwB4AaABAg', 'comment_text': 'A lot of truly funny animals. One of my favorites is at <a href="https://www.youtube.com/watch?v=NZCH87o_S3o&amp;t=281">4:41</a>', 'comment_author': '@zxaddictxz', 'comment_published_date': '2024-01-16T01:38:56Z'}]
# Inserted/Updated comment Ugyc5oqYrtLUcHLCQQB4AaABAg for video NZCH87o_S3o
# Inserted/Updated comment UgyGxOEJR5kvD-aBSYF4AaABAg for video NZCH87o_S3o
# Inserted/Updated comment UgyR_rriPIMFiO5LxwB4AaABAg for video NZCH87o_S3o
# Processing video: Wt71UNuWtNM
# Comments for video Wt71UNuWtNM: []
# Processing video: 3kMLWrwWZyk
# Comments for video 3kMLWrwWZyk: [{'comment_id': 'Ugw0gGtGH3V3X6fi7at4AaABAg', 'comment_text': 'Yarr video added kasa kar ta ho', 'comment_author': '@DAIMINFORMATIVEANIMALS', 'comment_published_date': '2024-01-12T14:36:34Z'}]
# Inserted/Updated comment Ugw0gGtGH3V3X6fi7at4AaABAg for video 3kMLWrwWZyk
# Processing video: 7PnHEi3jXzc
# Comments for video 7PnHEi3jXzc: [{'comment_id': 'Ugx6TNzPurChBCGFW2B4AaABAg', 'comment_text': 'Why disturb animals while sleeping ?! And those idiots who deress them... they are not Barbie dolls. Please respect their love, loyalty and dignity !', 'comment_author': '@MrsSandycat', 'comment_published_date': '2024-04-24T02:28:32Z'}, {'comment_id': 'UgxSVBqMG-sOfaBwyj14AaABAg', 'comment_text': 'Eu amo ver esses vídeos eles são muitos lindos fofos engraçados 😂😂😂😅😅❤❤de', 'comment_author': '@karenmachadodossantos8750', 'comment_published_date': '2024-01-31T00:15:25Z'}, {'comment_id': 'UgycwLe7o0gobjSgfyh4AaABAg', 'comment_text': '😢😮😅😊', 'comment_author': '@blessingorinya9903', 'comment_published_date': '2024-01-13T18:14:10Z'}]
# Inserted/Updated comment Ugx6TNzPurChBCGFW2B4AaABAg for video 7PnHEi3jXzc
# Inserted/Updated comment UgxSVBqMG-sOfaBwyj14AaABAg for video 7PnHEi3jXzc
# Inserted/Updated comment UgycwLe7o0gobjSgfyh4AaABAg for video 7PnHEi3jXzc
# Processing video: _l3V0yvZw_c
# Comments for video _l3V0yvZw_c: [{'comment_id': 'UgzmQA8k3A657Oc7Y4l4AaABAg', 'comment_text': 'Priceless video. A good laugh always.', 'comment_author': '@highphysics3617', 'comment_published_date': '2024-05-30T20:36:03Z'}, {'comment_id': 'UgxMi4hEpX8wWQSdjcp4AaABAg', 'comment_text': 'Very good video, thank you 😀', 'comment_author': '@MrsSandycat', 'comment_published_date': '2024-04-24T19:54:39Z'}, {'comment_id': 'Ugw3A2GG5fgw4DD4Mn14AaABAg', 'comment_text': 'Great video', 'comment_author': '@paulamoor3098', 'comment_published_date': '2024-02-19T20:46:19Z'}]
# Inserted/Updated comment UgzmQA8k3A657Oc7Y4l4AaABAg for video _l3V0yvZw_c
# Inserted/Updated comment UgxMi4hEpX8wWQSdjcp4AaABAg for video _l3V0yvZw_c
# Inserted/Updated comment Ugw3A2GG5fgw4DD4Mn14AaABAg for video _l3V0yvZw_c
# Processing video: bO4sY6tiSIk
# Comments for video bO4sY6tiSIk: []
# Processing video: xSC3LHh_a9g
# Comments for video xSC3LHh_a9g: [{'comment_id': 'Ugx5G5zLnJdI2ob-7qB4AaABAg', 'comment_text': '<a href="https://www.youtube.com/watch?v=xSC3LHh_a9g&amp;t=336">5:36</a>  WHY ??!', 'comment_author': '@MrsSandycat', 'comment_published_date': '2024-04-25T01:28:38Z'}]
# Inserted/Updated comment Ugx5G5zLnJdI2ob-7qB4AaABAg for video xSC3LHh_a9g
# Processing video: lC2avaCWokI
# Comments for video lC2avaCWokI: [{'comment_id': 'Ugzowni1TjEdEAELA9p4AaABAg', 'comment_text': '😂😂😂', 'comment_author': '@user-zu6gn5jz7d', 'comment_published_date': '2023-12-22T19:49:58Z'}]
# Inserted/Updated comment Ugzowni1TjEdEAELA9p4AaABAg for video lC2avaCWokI
# Processing video: Qa1NJx5Qn-8
# Comments for video Qa1NJx5Qn-8: [{'comment_id': 'UgwMXJJM03H5REwumCR4AaABAg', 'comment_text': '😂😂😂', 'comment_author': '@user-zu6gn5jz7d', 'comment_published_date': '2023-12-22T20:15:29Z'}]
# Inserted/Updated comment UgwMXJJM03H5REwumCR4AaABAg for video Qa1NJx5Qn-8
# Processing video: ZI1z1e3DpLI
# Comments for video ZI1z1e3DpLI: []
# Processing video: StiSPu3fNAs
# Comments for video StiSPu3fNAs: []
# Processing video: ttCbnyC8f3M
# Comments for video ttCbnyC8f3M: []
# Processing video: -neraz2yAhM
# Comments for video -neraz2yAhM: []
# Processing video: HiSsEp-zHTs
# Comments for video HiSsEp-zHTs: []
# Processing video: ZIYISLPDoTY
# Comments for video ZIYISLPDoTY: []
# Processing video: Rbj5aBvRZD0
# Comments for video Rbj5aBvRZD0: [{'comment_id': 'Ugz0sKFGbQDedZgRYnt4AaABAg', 'comment_text': '😂👍👍👍', 'comment_author': '@user-zu6gn5jz7d', 'comment_published_date': '2023-11-17T10:46:27Z'}]
# Inserted/Updated comment Ugz0sKFGbQDedZgRYnt4AaABAg for video Rbj5aBvRZD0
# Processing video: 6imcj_eewcU
# Comments for video 6imcj_eewcU: []
# Processing video: 16PgRSAqjkc
# Comments for video 16PgRSAqjkc: []
# Processing video: cj6wzVrgNww
# Comments for video cj6wzVrgNww: []
# Processing video: nPePCf36idE
# Comments for video nPePCf36idE: []
# Processing video: KCVGm58r7A8
# Comments for video KCVGm58r7A8: [{'comment_id': 'UgxHiRDYhMRE30s5QOR4AaABAg', 'comment_text': '😂😂😂', 'comment_author': '@user-zu6gn5jz7d', 'comment_published_date': '2023-12-22T20:39:06Z'}]
# Inserted/Updated comment UgxHiRDYhMRE30s5QOR4AaABAg for video KCVGm58r7A8
# Processing video: QR3pH-SHTYM
# Comments for video QR3pH-SHTYM: []
# Processing video: CzzAY8l3LpQ
# Comments for video CzzAY8l3LpQ: []
# Processing video: NFqrvkbhsAI
# Comments for video NFqrvkbhsAI: []
# Processing video: HHF9_YfFj6A
# Comments for video HHF9_YfFj6A: []
# Processing video: gYs7qKfhTsg
# Comments for video gYs7qKfhTsg: [{'comment_id': 'UgyOPYb_EqKDhFrr6gl4AaABAg', 'comment_text': 'Еще бы под хвостом лизнул.', 'comment_author': '@user-vk2kw8py9v', 'comment_published_date': '2023-10-10T17:56:23Z'}, {'comment_id': 'UgwAJKV6vLCyKnITdtJ4AaABAg', 'comment_text': 'Опять эта обезьяна собаку мучает!', 'comment_author': '@user-rq1il9xw6p', 'comment_published_date': '2023-10-09T18:16:53Z'}]
# Inserted/Updated comment UgyOPYb_EqKDhFrr6gl4AaABAg for video gYs7qKfhTsg
# Inserted/Updated comment UgwAJKV6vLCyKnITdtJ4AaABAg for video gYs7qKfhTsg
# Processing video: AZ-s0C7lnPE
# Comments for video AZ-s0C7lnPE: []
# Processing video: NKA8EMtLxS0
# An error occurred while fetching comments: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=NKA8EMtLxS0&maxResults=50&key=AIzaSyAbUPGkECjLGTipq6KipdkOrfg5KXX5QBg&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Comments for video NKA8EMtLxS0: []
# Processing video: Kj4lne80kJ4
# Comments for video Kj4lne80kJ4: []
# Processing video: S38jA79loGs
# Comments for video S38jA79loGs: [{'comment_id': 'UgxERc_mXX5AJSoKDop4AaABAg', 'comment_text': 'Hi can u help me to do this project', 'comment_author': '@rihanafcparveen9530', 'comment_published_date': '2024-05-24T03:51:13Z'}, {'comment_id': 'UgxVOW-rn7ipxZzJinl4AaABAg', 'comment_text': 'If u want detailed explanation about this project, pls comment me😎', 'comment_author': '@RKaleeswari-08', 'comment_published_date': '2024-01-03T06:10:22Z'}]
# Inserted/Updated comment UgxERc_mXX5AJSoKDop4AaABAg for video S38jA79loGs
# Inserted/Updated comment UgxVOW-rn7ipxZzJinl4AaABAg for video S38jA79loGs
# MySQL connection closed.
